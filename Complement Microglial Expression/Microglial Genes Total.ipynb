# %% [markdown]
# # Fetch the datasets table

# %%
import cellxgene_census

census = cellxgene_census.open_soma()
census_datasets = census["census_info"]["datasets"].read().concat().to_pandas()

# for convenience, indexing on the soma_joinid which links this to other census data.
# Indexing by soma_joinid breaks slicing dataset by soma_joinid
census_datasets = census_datasets.set_index("soma_joinid")

# Filter to only include the "Human Brian Cell Atlas v1.0" by the collection id == 283d65eb-dd53-496d-adb7-7570c7caa443
# census_datasets[census_datasets.collection_id == "283d65eb-dd53-496d-adb7-7570c7caa443"]

# Filter to only include the Microglia Supercluster by the dataset id == 700aed19-c16e-4ba8-9191-07da098a8626
# census_datasets[census_datasets.dataset_id == "700aed19-c16e-4ba8-9191-07da098a8626"]

census_datasets
# Out:
# The "stable" release is currently 2025-01-30. Specify 'census_version="2025-01-30"' in future calls to open_soma() to ensure data consistency.
#                                                       citation  \
# soma_joinid
# 0            Publication: https://doi.org/10.1016/j.isci.20...
# 1            Publication: https://doi.org/10.1016/j.isci.20...
# 2            Publication: https://doi.org/10.1016/j.isci.20...
# 3            Publication: https://doi.org/10.1016/j.isci.20...
# 4            Publication: https://doi.org/10.1038/s41591-02...
# ...                                                        ...
# 1568         Publication: https://doi.org/10.1038/s41586-02...
# 1569         Publication: https://doi.org/10.1126/science.a...
# 1570         Publication: https://doi.org/10.1038/s41586-02...
# 1571         Publication: https://doi.org/10.1038/s41593-02...
# 1572         Publication: https://doi.org/10.1038/s41593-02...
#
#                                     collection_id  \
# soma_joinid
# 0            8e880741-bf9a-4c8e-9227-934204631d2a
# 1            8e880741-bf9a-4c8e-9227-934204631d2a
# 2            8e880741-bf9a-4c8e-9227-934204631d2a
# 3            8e880741-bf9a-4c8e-9227-934204631d2a
# 4            a96133de-e951-4e2d-ace6-59db8b3bfb1d
# ...                                           ...
# 1568         45d5d2c3-bc28-4814-aed6-0bb6f0e11c82
# 1569         e5f58829-1a66-40b5-a624-9046778e74f5
# 1570         45d5d2c3-bc28-4814-aed6-0bb6f0e11c82
# 1571         1ca90a2d-2943-483d-b678-b809bf464c30
# 1572         1ca90a2d-2943-483d-b678-b809bf464c30
#
#                                                collection_name  \
# soma_joinid
# 0            High Resolution Slide-seqV2 Spatial Transcript...
# 1            High Resolution Slide-seqV2 Spatial Transcript...
# 2            High Resolution Slide-seqV2 Spatial Transcript...
# 3            High Resolution Slide-seqV2 Spatial Transcript...
# 4            HTAN/HTAPP Broad - Spatio-molecular dissection...
# ...                                                        ...
# 1568         A single-cell transcriptional timelapse of mou...
# 1569                                            Tabula Sapiens
# 1570         A single-cell transcriptional timelapse of mou...
# 1571         SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
# 1572         SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
#
#                          collection_doi  \
# soma_joinid
# 0            10.1016/j.isci.2022.104097
# 1            10.1016/j.isci.2022.104097
# 2            10.1016/j.isci.2022.104097
# 3            10.1016/j.isci.2022.104097
# 4            10.1038/s41591-024-03215-z
# ...                                 ...
# 1568         10.1038/s41586-024-07069-w
# 1569            10.1126/science.abl4896
# 1570         10.1038/s41586-024-07069-w
# 1571         10.1038/s41593-024-01774-5
# 1572         10.1038/s41593-024-01774-5
#
#                                           collection_doi_label  \
# soma_joinid
# 0                              Marshall et al. (2022) iScience
# 1                              Marshall et al. (2022) iScience
# 2                              Marshall et al. (2022) iScience
# 3                              Marshall et al. (2022) iScience
# 4                             Klughammer et al. (2024) Nat Med
# ...                                                        ...
# 1568                                  Qiu et al. (2024) Nature
# 1569         The Tabula Sapiens Consortium* et al. (2022) S...
# 1570                                  Qiu et al. (2024) Nature
# 1571                        Gabitto et al. (2024) Nat Neurosci
# 1572                        Gabitto et al. (2024) Nat Neurosci
#
#                                        dataset_id  \
# soma_joinid
# 0            4eb29386-de81-452f-b3c0-e00844e8c7fd
# 1            78d59e4a-82eb-4a61-a1dc-da974d7ea54b
# 2            add5eb84-5fc9-4f01-982e-a346dd42ee82
# 3            b020294c-ab82-4547-b5a7-63d8ffa575ed
# 4            d7476ae2-e320-4703-8304-da5c42627e71
# ...                                           ...
# 1568         dcfa2614-7ca7-4d82-814c-350626eccb26
# 1569         53d208b0-2cfd-4366-9866-c3c6114081bc
# 1570         dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3
# 1571         c2876b1b-06d8-4d96-a56b-5304f815b99a
# 1572         6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
#
#                                dataset_version_id  \
# soma_joinid
# 0            f76861bb-becb-4eb7-82fc-782dc96ccc7f
# 1            7d7ec1b6-6e3f-4aaa-9442-4b22f3424396
# 2            de54aed8-4f73-48f6-9229-418a840e2d82
# 3            abe4fce1-0859-4a56-ad1e-734d79f0e6c8
# 4            863fc5e4-bd4a-4681-9c3d-0ee7ef54e327
# ...                                           ...
# 1568         3002a659-a1a9-4406-9976-99e658e1fbb5
# 1569         10df7690-6d10-4029-a47e-0f071bb2df83
# 1570         3817734b-0f82-433b-8c38-55b214200fff
# 1571         c32964d2-3339-441f-8e56-7177234c7876
# 1572         d3427e8c-c55d-4d4e-b15b-1a8774cd3a4b
#
#                                                  dataset_title  \
# soma_joinid
# 0             Spatial transcriptomics in mouse: Puck_191112_05
# 1             Spatial transcriptomics in mouse: Puck_191112_08
# 2             Spatial transcriptomics in mouse: Puck_191109_20
# 3             Spatial transcriptomics in mouse: Puck_191112_13
# 4                                 HTAPP-330-SMP-1082 scRNA-seq
# ...                                                        ...
# 1568                              Major cell cluster: Mesoderm
# 1569                                Tabula Sapiens - All Cells
# 1570                            Whole dataset: Raw counts only
# 1571         Whole Taxonomy - MTG: Seattle Alzheimer's Dise...
# 1572         Whole Taxonomy - DLPFC: Seattle Alzheimer's Di...
#
#                                      dataset_h5ad_path  \
# soma_joinid
# 0            4eb29386-de81-452f-b3c0-e00844e8c7fd.h5ad
# 1            78d59e4a-82eb-4a61-a1dc-da974d7ea54b.h5ad
# 2            add5eb84-5fc9-4f01-982e-a346dd42ee82.h5ad
# 3            b020294c-ab82-4547-b5a7-63d8ffa575ed.h5ad
# 4            d7476ae2-e320-4703-8304-da5c42627e71.h5ad
# ...                                                ...
# 1568         dcfa2614-7ca7-4d82-814c-350626eccb26.h5ad
# 1569         53d208b0-2cfd-4366-9866-c3c6114081bc.h5ad
# 1570         dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3.h5ad
# 1571         c2876b1b-06d8-4d96-a56b-5304f815b99a.h5ad
# 1572         6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3.h5ad
#
#              dataset_total_cell_count
# soma_joinid
# 0                               10888
# 1                               10250
# 2                               12906
# 3                               15161
# 4                                 565
# ...                               ...
# 1568                          3267338
# 1569                          1136218
# 1570                         11441407
# 1571                          1226855
# 1572                          1309414
#
# [1573 rows x 10 columns]

# %% [markdown]
# # Identify all the genes measured in the dataset

# %%
# Grab the experiment containing human data, and the measurement therein with RNA
human = census["census_data"]["homo_sapiens"]
human_rna = human.ms["RNA"]

# The census-wide datasets
datasets_df = census["census_info"]["datasets"].read().concat().to_pandas()

presence_matrix = cellxgene_census.get_presence_matrix(census, organism="Homo sapiens", measurement_name="RNA")

var_df = human_rna.var.read().concat().to_pandas()

# Slice the dataset(s) of interest, and get the joinid(s)
dataset_joinids = datasets_df.loc[datasets_df.dataset_id == "700aed19-c16e-4ba8-9191-07da098a8626"].soma_joinid

# Slice the presence matrix by the first dimension, i.e., by dataset
var_joinids = presence_matrix[dataset_joinids, :].tocoo().col

# From the feature (var) dataframe, slice out features which have a joinid in the list.
var_df.loc[var_df.soma_joinid.isin(var_joinids)]
# Out:
#        soma_joinid       feature_id       feature_name  \
# 0                0  ENSG00000237491          LINC01409
# 1                1  ENSG00000188976              NOC2L
# 2                2  ENSG00000187642              PERM1
# 3                3  ENSG00000272512  ENSG00000272512.1
# 4                4  ENSG00000188290               HES4
# ...            ...              ...                ...
# 60383        60383  ENSG00000285470            TUSC2P1
# 60384        60384  ENSG00000286120  ENSG00000286120.1
# 60385        60385  ENSG00000286173  ENSG00000286173.1
# 60386        60386  ENSG00000286744  ENSG00000286744.1
# 60426        60426  ENSG00000289084  ENSG00000289084.1
#
#                              feature_type  feature_length       nnz  \
# 0                                  lncRNA            1059   7958785
# 1                          protein_coding            1244  18685092
# 2                          protein_coding            2765    664016
# 3                                  lncRNA            2086    927207
# 4                          protein_coding             961  19206715
# ...                                   ...             ...       ...
# 60383                processed_pseudogene            1237      2150
# 60384  transcribed_unprocessed_pseudogene             457         6
# 60385  transcribed_unprocessed_pseudogene             457         3
# 60386              unprocessed_pseudogene             102        74
# 60426                              lncRNA             637   4845634
#
#        n_measured_obs
# 0            92252850
# 1           105784525
# 2            95688802
# 3            91649589
# 4           105542421
# ...               ...
# 60383        23175703
# 60384        19614003
# 60385        19614003
# 60386        19229873
# 60426        20936510
#
# [59236 rows x 7 columns]

# %% [markdown]
# # Normalize the gene expression?
